# %%
import pandas as pd
import random
import time
from llama_index.experimental.query_engine import PandasQueryEngine
from llama_index.core import Settings
from llama_index.llms.openai_like import OpenAILike

# ================= 配置 =================
MY_API_KEY = "sk-bf54fbae108748da859244787c7445d0" # 记得换回你的 Key
DATASET_PATH = "WikiTableQuestions_test.csv" # 假设你下载了完整数据集，或者我们用之前的 csv
SAMPLE_SIZE = 300  # 🎯 目标：跑 300-500 条
OUTPUT_FILE = "large_benchmark_results.csv"

# 初始化 LLM
llm = OpenAILike(
    model="deepseek-chat",
    api_base="https://api.deepseek.com",
    api_key=MY_API_KEY,
    is_chat_model=True,
    temperature=0
)
Settings.llm = llm

# ================= 核心逻辑 =================

def get_cot_prompt(query):
    """构造 Chain-of-Thought Prompt"""
    return f"{query}\nLet's think step by step. First, analyze the column names. Then, write the pandas code."

def run_large_scale_test():
    # 1. 加载数据 (你需要先下载 WTQ 的完整 csv，或者我们模拟生成更多数据)
    # 这里假设你有一个包含所有问题的大表
    # 如果没有，我们可以先用之前的随机抽样逻辑，循环抽取
    
    # 临时替代方案：用之前的逻辑随机生成任务列表
    # (在实际投稿中，你需要去 huggingface 下载 WikiTableQuestions 的 test.csv)
    print(f"🚀 准备运行大规模测试 (N={SAMPLE_SIZE})...")
    
    results = []
    
    # 模拟循环 (实际请替换为真实数据加载)
    for i in range(SAMPLE_SIZE):
        # ... 这里填入加载真实数据的代码 ...
        # task = ...
        pass
        
    print("⚠️ 提示：为了运行这个脚本，你需要下载 WikiTableQuestions 的完整数据文件。")
    print("目前你的论文是基于 30 个样本的，我们先用这个逻辑扩充。")

    # TODO: 这里需要你确认是否要我去帮你写一个“自动下载并清洗 WTQ 数据”的脚本？
    # 否则光跑空循环没有意义。

if __name__ == "__main__":
    run_large_scale_test()
# Out:
# 🚀 准备运行大规模测试 (N=300)...
# ⚠️ 提示：为了运行这个脚本，你需要下载 WikiTableQuestions 的完整数据文件。
# 目前你的论文是基于 30 个样本的，我们先用这个逻辑扩充。
